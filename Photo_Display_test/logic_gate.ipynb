# %%
# !pip install cocotb cocotb-test
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for cocotb-test: filename=cocotb_test-0.2.6-py3-none-any.whl size=17055 sha256=88fc1277e6ea4cf4e1699e590c666fc146b1969255fc6d38b7ca42dc357e367f
#   Stored in directory: c:\users\rujut\appdata\local\pip\cache\wheels\be\55\bd\c0349fc2091bd904a55a25c52d1a95999d0eb23e9dd62a3d17
# Successfully built cocotb-test
# ...
